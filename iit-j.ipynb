# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # PRACTICAL SESSION 1

# %%
import matplotlib.pyplot as plt
import numpy  as np
x_data=np.array([1,2,3,4,5,6,7,8])
y_data=np.array([2.1,3.9,6.2,7.8,10.1,12.3,14.0,15.8])

#creating a model line(linear fit)
coeffs=np.polyfit(x_data,y_data,1)
x_line=np.linspace(1,8,100)
y_line=coeffs[0]*x_line+coeffs[1]

#create plot
plt.figure(figsize=(8,6))
plt.scatter(x_data,y_data,color='blue',s=80,alpha=0.7,label='Data Points')
plt.plot(x_line,y_line,color='green',linewidth=2,label="Model Line")

#Add labels and formatting
plt.xlabel("xvalues",fontsize=12)
plt.ylabel("yvalues",fontsize=12)
plt.title("Scatter Plot with Linear Model",fontsize=14)
plt.legend()
plt.grid(True,alpha=0.3)
plt.show()

# %%
#create a vector which shows study hours in a week of multiple students in 3D matrix.
import numpy as np
study_hours=np.array([[2,3,4,5,6,4,3],[1,2,3,3,2,1,5]])
print(study_hours)
# Out:
# [[2 3 4 5 6 4 3]
#  [1 2 3 3 2 1 5]]

# %%
#line plot example
import matplotlib.pyplot as plt
x=np.arange(1,6)
y=x**2

plt.plot(x,y,label='y=x^2')
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.title("Line Plot Example")

plt.legend()
plt.show()

# %%
#Scatter Plot Example

maths=[60,70,80,90,100]
science=[65,68,78,85,95]

plt.scatter(maths,science)
plt.xlabel("Maths Label")
plt.ylabel("Science Label")
plt.title("Maths vs Science Marks Comparison of Students")
plt.show()

# %%
#Dataset
sizes=np.array([650,800,1200,1500,2000])
prices=np.array([50,70,110,140,200])

plt.scatter(sizes,prices,label='data')
plt.xlabel('House Size in sq ft')
plt.ylabel('Price in Lakhs')

m,c=0.11, -20
line= m*sizes + c
plt.plot(sizes, line, color='green',label='our Hint')
plt.legend()
plt.show()
# Give me values of m and c after hit and trial which makes line closer to scatter points

# %% [markdown]
# # PRACTICAL SESSION 2

# %%
import matplotlib.pyplot as plt
import numpy as np

#generate sample data
x=np.linspace(0,10,50)
y_scatter = 2*x+ np.random.normal(0,2,50)
y_line1=2*x+1
y_line2=1.5*x+1

#create the plot
plt.scatter(x,y_scatter,color="#FF6B6B", alpha=0.6 ,s=40, label='Data Points')

#first line with custom style
plt.plot(x,y_line1, linestyle='--',color="#4ECDC4", linewidth=2.5, label="Trend Line 1")

#second line with custom style
plt.plot(x,y_line2, linestyle='--',color="#74B9FF", linewidth=2.5, label="Trend Line 2")

#Customization
plt.xlabel('X Values', fontsize=12)
plt.ylabel('Y Values', fontsize=12)
plt.title("Customized Multi Plot Visualization", fontsize=14, fontweight="bold")
plt.legend(frameon=True, shadow=True)
plt.grid(True,alpha=0.3)
plt.show()
